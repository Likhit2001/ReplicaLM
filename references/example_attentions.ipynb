# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
B, T, C = 4, 8, 2
x = torch.randn(B, T, C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %% [markdown]
# #Basic Self attention

# %%
head_size =  16
key = nn.Linear(C,head_size,bias=False)
query = nn.Linear(C,head_size,bias=False)
value = nn.Linear(C,head_size,bias=False)

k = key(x)   # B, T, head_size
q = query(x) # B, T, head_size
v = value(x)

wei = q @ k.transpose(-2,-1) # B , T , T (here each token is attenteding to the other token)

tril = torch.tril(torch.ones(T,T))   # so that curr element doesn't attend to the next element
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=1)

print(wei.shape)

out = wei @ v

print(out.shape)
# Out:
# torch.Size([4, 8, 8])
# torch.Size([4, 8, 16])
